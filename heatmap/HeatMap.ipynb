# %% [markdown]
# ## Geotemporal Emergency Heatmap
# ### Tutorial for RapidSOS data
# #### Aidan Holloway-Bidwell

# %% [markdown]
# First, if we don't already have data files that we want to visualize, we run the data script to create .csv files in data/ that hold our temperature and call data.

# %%
import data_script as script
script.main()

# %% [markdown]
# Now that we have some data to work with, we can make some heatmaps with the weather or call data! For call data we'll want to just count up the points, and thus pass the enum type datatype.COUNT to the instantiation of the heatmap. If we are working with values at coordinates, like temperature, we'll pass datatype.VALUES.

# %%
import heatmap as m
display = m.heatmap('data/emergencies.csv',datatype=m.datatype.COUNT)
# Out:
# 4
# [ 0.  1.  2.  3.  4.]
# Number of points:  50
# Cell size:  0.02841 miles, or  0.04572  kilometers.
