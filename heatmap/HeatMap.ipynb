# %% [markdown]
# ## Geotemporal Emergency Heatmap
# ### RapidSOS
# #### Aidan Holloway-Bidwell

# %%
import heatmap as md
display = md.heatmap('emergencies.csv', 'DAY', 10, 10)
# Out:
# http://server.arcgisonline.com/ArcGIS/rest/services/ESRI_StreetMap_World_2D/MapServer/export?bbox=-72.67221291999999,42.33031207999999,-72.65987908,42.34264592&bboxSR=4326&imageSR=4326&size=12000,12000&dpi=96&format=png32&f=image

# %%
## red_black_tree

class rbtree:

    class node:

        def __init__(self, color, val, parent=None, left=None, right=None):
            self.color = color
            self.val = val
            self.parent = parent
            self.left = left
            self.right = right
            
    def __init__(self):
        self.root = None
        
    def binary_insert(self, root, n):
        if root == None:
            root = n
        elif (n.val > root.val):
            if root.right == None:
                root.right = n
                n.parent = root
            else:
                binary_insert(root.right, n)
        elif (n.val < root.val):
            if root.left == None:
                root.left = n
                n.parent = root
            else:
                binary_insert(root.left,n)
        else:
            return
        
    def balance(self, n):
        
        p = n.parent
        gp = p.parent
        result = None
        if n == self.root:
            self.root.color = 'B'
        elif ((p.val > gp.val) && (gp.left.color == 'R')):
            p.color = 'B'
            gp.left.color = 'B'
            result = gp
        elif ((p.val < gp.val) && (gp.right.color == 'R')):
            p.color = 'B'
            gp.right.color = 'B'
            result = gp
        elif ((p.val < gp.val) && (n.val < p.val)):
            tmp = p.right
            tmpc = p.color
            tempp = gp.parent
            p.right = gp
            gp.left = tmp
            p.color = gp.color
            gp.color = tmpc
            gp.parent = p
            p.parent = tempp
            result = None
        elif ((p.val < gp.val) && (n.val > p.val)):
            tmp = n.left
            n.left = n.p
            result = balance()
        elif ((p.val > gp.val) && (n.val > p.val)):
            
        else:
            
        return result
        
    def insert(self, n)
        if self.root == None:
            self.root = n
            self.root.color = 'B'
        else:
            n.color = 'R'
            binary_insert(self.root, n)
            if n.parent.color == 'R':
                x = n
                while x != None:
                    x = balance(n)
# Out:
#   File "<ipython-input-1-15aef713df53>", line 42
#     elif ((p.val > gp.val) && (gp.left.color == 'R')):
#                             ^
# SyntaxError: invalid syntax
