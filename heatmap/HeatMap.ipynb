# %% [markdown]
# ## Geotemporal Emergency Heatmap
# ### RapidSOS
# #### Aidan Holloway-Bidwell

# %%
import heatmap as md
display = md.heatmap('emergencies.csv')
# Out:
# Cell size:  0.02841 miles, or  0.04572  kilometers.

# %%
display.change_numcells(9)
# Out:
# Cell size:  0.09469 miles, or  0.15238  kilometers.
